# %% [markdown]
# ## Pandas
# Najpopularniejsza biblioteka w Pythonie stosowana do analizy i przetwarzania danych\
# posługuje sie tzw. **DataFrame, Series**

# %%
from io import StringIO
# !pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ---------------------------------------  10.7/11.0 MB 83.9 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 68.7 MB/s eta 0:00:00
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#
#    ---------------------------------------- 0/3 [pytz]
#    ---------------------------------------- 0/3 [pytz]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    ------------- -------------------------- 1/3 [tzdata]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
#    -------------------------- ------------- 2/3 [pandas]
# ...

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.2

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.10.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      25.1.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# attrs                     25.3.0
# babel                     2.17.0
# beautifulsoup4            4.13.5
# bleach                    6.2.0
# certifi                   2025.8.3
# cffi                      1.17.1
# charset-normalizer        3.4.3
# colorama                  0.4.6
# comm                      0.2.3
# debugpy                   1.8.16
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.0
# fastjsonschema            2.21.2
# fqdn                      1.5.1
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.10
# ipykernel                 6.30.1
# ...

# %%
product_data = {
    "product a": [13, 20, 0, 10],
    "product b": [10, 30, 17, 10],
    "product c": [6, 9, 10, 0]
}

# %%
product_data
# Out:
# {'product a': [13, 20, 0, 10],
#  'product b': [10, 30, 17, 10],
#  'product c': [6, 9, 10, 0]}

# %%
miasta = ["Kilece", "Poznań", "Warszawa", "Kraków"]

# %%
# tworzymy DataFrame (tabele)
data = pd.DataFrame(product_data, index=miasta)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 # tworzymy DataFrame (tabele)
# ----> 2 data = pd.DataFrame(product_data, index=miasta)
#
# NameError: name 'product_data' is not defined

# %%
data
# Out:
#           product a  product b  product c
# Kilece           13         10          6
# Poznań           20         30          9
# Warszawa          0         17         10
# Kraków           10         10          0

# %%
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 print(data)
#
# NameError: name 'data' is not defined

# %% [markdown]
# matplotlib - wykresy

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 8.1/8.1 MB 50.3 MB/s eta 0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 124.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.0 MB ? eta -:--:--
#    ---------------------------------------- 7.0/7.0 MB 143.1 MB/s eta 0:00:00
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# ...
#
#    ---------------------------------------- 0/7 [pyparsing]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
#    ----- ---------------------------------- 1/7 [pillow]
# ...

# %%
from matplotlib import pyplot as plt

# %%
data['product b'].plot(kind="hist", bins=20, title='product b')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data.loc["Warszawa"] > 10
# Out:
# product a    False
# product b     True
# product c    False
# Name: Warszawa, dtype: bool

# %%
df = pd.read_csv('data/AAPL_stock_price_example.csv')

# %%
df
# Out:
#                                                    0
# 0                                Part of a series on
# 1                                 Sustainable energy
# 2  Energy conservation Arcology Building insulati...
# 3  Renewable energy Biofuel Sustainable Biogas Bi...
# 4  Sustainable transport Green vehicle Electric v...
# 5                  Category  Renewable energy portal
# 6                                                vte

# %%
df.describe()
# Out:
#             Close
# count  229.000000
# mean   201.477598
# std     28.246961
# min    142.190002
# 25%    182.539993
# 50%    200.720001
# 75%    213.279999
# max    267.100006

# %%
# !pip install openpyxl
# pozwala zapisać dane excelowe
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    ---------------------------------------- 2/2 [openpyxl]
#
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# ...

# %%
import openpyxl

df.to_excel(r"C:\Users\CSComarch\PycharmProjects\PythonProject\day2\data\test.excel2.xlsx", index=False)
# df.to_excel(r"C:\Users\CSComarch\PycharmProjects\PythonProject\day2\data\test.excel2.xlsx", index=True)

# %%
df = pd.read_csv("data/evolution_of_data_analysis.csv", delimiter="|")

# %%
df.describe()
# Out:
#               Year
# count    42.000000
# mean   1993.833333
# std      18.876901
# min    1945.000000
# 25%    1987.500000
# 50%    1999.000000
# 75%    2006.750000
# max    2018.000000

# %%
df.info() # sprawdzenie typów danych, null i podobne
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 7 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Year                              42 non-null     int64
#  1   Decade                            42 non-null     object
#  2   Milestone Title                   42 non-null     object
#  3   Milestone Event                   42 non-null     object
#  4   Why Important                     42 non-null     object
#  5   Reference                         39 non-null     object
#  6   People Process or Technology Tag  42 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 2.4+ KB

# %%
df.shape
# Out:
# (42, 7)

# %%
movies_df = pd.read_csv("data/IMDB-Movie-Data.csv", index_col="Title")
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %%
# wypisze pierwszych 5 wierszy

# %%
movies_df.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
movies_df.drop_duplicates()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.rename(columns={"Runtime (Minutes)":"Runtime"}) # zwraca nową tablicę
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.rename(columns={"Runtime (Minutes)": "Runtime"}, inplace=True) # zmienia w oryginalnej

# %%
movies_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# ...

# %%
movies_df.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# ...

# %%
movies_df.columns = [col.lower() for col in movies_df]
movies_df.tail() # pięc ostatnich wierszy
# Out:
#                         rank                  genre  \
# Title
# Secret in Their Eyes     996    Crime,Drama,Mystery
# Hostel: Part II          997                 Horror
# Step Up 2: The Streets   998    Drama,Music,Romance
# Search Party             999       Adventure,Comedy
# Nine Lives              1000  Comedy,Family,Fantasy
#
#                                                               description  \
# Title
# Secret in Their Eyes    A tight-knit team of rising investigators, alo...
# Hostel: Part II         Three American college students studying abroa...
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 director  \
# Title
# Secret in Their Eyes           Billy Ray
# Hostel: Part II                 Eli Roth
# Step Up 2: The Streets        Jon M. Chu
# ...

# %%
movies_df.isnull().sum().to_json(r'C:\Users\CSComarch\PycharmProjects\PythonProject\day2\data\dane2345.json')

# %%
# usunięcie elementów null
movies_df.dropna()
# Out:
#                           rank                     genre  \
# Title
# Guardians of the Galaxy      1   Action,Adventure,Sci-Fi
# Prometheus                   2  Adventure,Mystery,Sci-Fi
# Split                        3           Horror,Thriller
# Sing                         4   Animation,Comedy,Family
# Suicide Squad                5  Action,Adventure,Fantasy
# ...                        ...                       ...
# Resident Evil: Afterlife   994   Action,Adventure,Horror
# Project X                  995                    Comedy
# Hostel: Part II            997                    Horror
# Step Up 2: The Streets     998       Drama,Music,Romance
# Nine Lives                1000     Comedy,Family,Fantasy
#
#                                                                 description  \
# Title
# Guardians of the Galaxy   A group of intergalactic criminals are forced ...
# Prometheus                Following clues to the origin of mankind, a te...
# ...

# %%
# wczytanie kolumny
rev = movies_df['revenue (millions)']
rev.head()
# Out:
# Title
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
# Name: revenue (millions), dtype: float64

# %%
rev.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Series name: revenue (millions)
# Non-Null Count  Dtype
# --------------  -----
# 872 non-null    float64
# dtypes: float64(1)
# memory usage: 47.9+ KB

# %%
# średnia
rev.mean()
# Out:
# np.float64(82.95637614678898)

# %%
movies_df.describe()
# Out:
#               rank         year      runtime       rating         votes  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000   113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962    18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000    66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000   100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000   111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000   123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000   191.000000     9.000000  1.791916e+06
#
#        revenue (millions)   metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# 50%             47.985000   59.500000
# 75%            113.715000   72.000000
# ...

# %%
movies_df.sort_values(by='rating') # sortowanie po kolumnie rating
# Out:
#                          rank                     genre  \
# Title
# Disaster Movie            830                    Comedy
# Don't Fuck in the Woods    43                    Horror
# Dragonball Evolution      872  Action,Adventure,Fantasy
# Tall Men                  648   Fantasy,Horror,Thriller
# Wrecker                   969    Action,Horror,Thriller
# ...                       ...                       ...
# Interstellar               37    Adventure,Drama,Sci-Fi
# The Intouchables          250    Biography,Comedy,Drama
# Inception                  81   Action,Adventure,Sci-Fi
# Dangal                    118    Action,Biography,Drama
# The Dark Knight            55        Action,Crime,Drama
#
#                                                                description  \
# Title
# Disaster Movie           Over the course of one evening, an unsuspectin...
# Don't Fuck in the Woods  A group of friends are going on a camping trip...
# ...

# %%
movies_df.groupby(['genre']).agg({'year':'count'}).sort_values(by="year", ascending=False)
# count - liczy wszystkie bez NaN
# Out:
#                           year
# genre
# Action,Adventure,Sci-Fi     50
# Drama                       48
# Comedy,Drama,Romance        35
# Comedy                      32
# Drama,Romance               31
# ...                        ...
# Mystery,Thriller,Western     1
# Romance,Sci-Fi,Thriller      1
# Romance,Sci-Fi               1
# Sci-Fi,Thriller              1
# Thriller,War                 1
#
# [207 rows x 1 columns]

# %%
store1 = pd.read_csv("data/Store1.csv")
store1.head()
# Out:
#   Months  Grocery_sales  Stationary_sales
# 0    Jan             16                57
# 1    Jan             44               139
# 2    Jan             15                85
# 3    Jan             59                 8
# 4    Jan             36               106

# %%
store2 = pd.read_csv("data/Store2.csv")
store2.head()
# Out:
#   Months  Grocery_sales  Stationary_sales
# 0    Jan             36                84
# 1    Jan             51                63
# 2    Jan             17                71
# 3    Jan             48                65
# 4    Jan             57                66

# %%
sales_store1 = (store1[['Grocery_sales', 'Stationary_sales']].sum()).sum()
sales_store1
# Out:
# np.int64(6082)

# %%
month_sales1 = store1.groupby(['Months'])[['Grocery_sales', 'Stationary_sales']].agg('sum').agg('sum', axis=1)
month_sales1
# Out:
# Months
# Feb    1744
# Jan    1467
# Mar    2871
# dtype: int64

# %%
month_sales1 = store1.groupby(['Months'])[['Grocery_sales', 'Stationary_sales']].agg('sum').agg('sum', axis=0)
month_sales1
# Out:
# Grocery_sales       2097
# Stationary_sales    3985
# dtype: int64

# %%
store_greater = store1[store1['Stationary_sales'].gt(store2['Stationary_sales'])]
store_greater
# Out:
# C:\Users\CSComarch\AppData\Local\Temp\ipykernel_11052\785796314.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   store_greater = store1[store1['Stationary_sales'].gt(store2['Stationary_sales'])]
#    Months  Grocery_sales  Stationary_sales
# 1     Jan             44               139
# 2     Jan             15                85
# 4     Jan             36               106
# 5     Jan             27               136
# 6     Jan             74               116
# 7     Jan             63               142
# 8     Jan             65               129
# 9     Jan             12               138
# 10    Feb             34               112
# 11    Feb             73               100
# 12    Feb             45               135
# 13    Feb             31                13
# 14    Feb             61                51
# 16    Feb             20               141
# 17    Feb             18                72
# 18    Feb             60               134
# ...

# %% [markdown]
# ![image.png](attachment:ceb15395-f160-4952-bccb-8ab71f673927.png)

# %%
import pandas as pd

# %%
dfo = pd.read_excel("data/dog_food_orders.xlsx", engine="openpyxl")

# %%
dfo
# Out:
#                   product  wholesale_price   msrp  qty_ordered  qty_shipped
# 0           skippys_dream             8.99  18.38          100          100
# 1           just_the_beef             4.99  10.43          200          195
# 2        potatos_and_lamb             5.19  11.43           50           50
# 3  turkey_and_cranberries             5.98  12.00           50           50
# 4            roasted_duck             9.59  17.48           15           15

# %%
# !pip install lxml # potrzebne do read_html
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ---------------------------------------- 4.0/4.0 MB 30.0 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# data_url ='https://en.wikipedia.org/wiki/Wind_power'
# data = pd.read_html(data_url)
# data[1]

import requests
import pandas as pd
from io import StringIO
url = "https://en.wikipedia.org/wiki/Wind_power"

headers = {
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/119.0 Safari/537.36"
}

resp = requests.get(url, headers=headers, timeout=20)
resp.raise_for_status()           # podniesie wyjątek, jeśli np. 403/404

html = StringIO(resp.text) # wymagane dla nowszych wersji Pandas
tables = pd.read_html(html)  # lista DataFrame’ów z tabeli na stronie
print(len(tables))
df = tables[0]                    # np. pierwsza tabela
print(df.head())
# Out:
# 21
#                                                    0
# 0                                Part of a series on
# 1                                 Sustainable energy
# 2  Energy conservation Arcology Building insulati...
# 3  Renewable energy Biofuel Sustainable Biogas Bi...
# 4  Sustainable transport Green vehicle Electric v...

# %%
tables[1]
# Out:
#                  Wind farm  Capacity (MW)        Country  Refs
# 0          Gansu Wind Farm           7965          China  [21]
# 1      Muppandal Wind Farm           1500          India  [22]
# 2  Alta (Oak Creek-Mojave)           1320  United States  [23]
# 3      Jaisalmer Wind Park           1064          India  [24]

# %%
tables[1].to_csv(r'C:\Users\CSComarch\PycharmProjects\PythonProject\day2\data\tabela_wind_power.csv')
