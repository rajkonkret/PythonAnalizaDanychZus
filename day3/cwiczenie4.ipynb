# %%
import pandas as pd

# %%
pd.read_csv('data/bike_share_UCS_2_LE_BOM.tsv', encoding='utf_16_le', sep="\t")
# Out:
#            dteday  hr  cnt
# 0        1/1/2011   0   16
# 1        1/1/2011   1   40
# 2        1/1/2011   2   32
# 3        1/1/2011   3   13
# 4        1/1/2011   4    1
# ...           ...  ..  ...
# 17374  12/31/2012  19  119
# 17375  12/31/2012  20   89
# 17376  12/31/2012  21   90
# 17377  12/31/2012  22   61
# 17378  12/31/2012  23   49
#
# [17379 rows x 3 columns]

# %% [markdown]
# ----

# %%
data = pd.read_csv("data/thyroid.tsv", encoding='utf_16_le', sep="\t")

# %%
data
# Out:
#      age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0     41   F            f                  f                         f    f
# 1     23   F            f                  f                         f    f
# 2     46   M            f                  f                         f    f
# 3     70   F            t                  f                         f    f
# 4     70   F            f                  f                         f    f
# ...   ..  ..          ...                ...                       ...  ...
# 2795  70   M            f                  f                         f    f
# 2796  73   M            f                  t                         f    f
# 2797  75   M            f                  f                         f    f
# 2798  60   F            f                  f                         f    f
# 2799  81   F            f                  f                         f    f
#
# ...

# %%
data.describe()
# Out:
#              value
# count  2800.000000
# mean   1895.603214
# std    1091.130220
# min       1.000000
# 25%     955.750000
# 50%    1913.000000
# 75%    2837.500000
# max    3772.000000

# %%
data.head()
# Out:
#   age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0  41   F            f                  f                         f    f
# 1  23   F            f                  f                         f    f
# 2  46   M            f                  f                         f    f
# 3  70   F            t                  f                         f    f
# 4  70   F            f                  f                         f    f
#
#   pregnant thyroid_surgery I131_treatment query_hypothyroid  ...  TT4  \
# 0        f               f              f                 f  ...  125
# 1        f               f              f                 f  ...  102
# 2        f               f              f                 f  ...  109
# 3        f               f              f                 f  ...  175
# 4        f               f              f                 f  ...   61
#
#   T4U_measured   T4U FTI_measured  FTI TBG_measured TBG referral_source  \
# ...

# %%
data.tail() # pięć ostatnich
# Out:
#      age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 2795  70   M            f                  f                         f    f
# 2796  73   M            f                  t                         f    f
# 2797  75   M            f                  f                         f    f
# 2798  60   F            f                  f                         f    f
# 2799  81   F            f                  f                         f    f
#
#      pregnant thyroid_surgery I131_treatment query_hypothyroid  ...  TT4  \
# 2795        f               f              f                 f  ...  155
# 2796        f               f              f                 f  ...   63
# 2797        f               f              f                 f  ...  147
# 2798        f               f              f                 f  ...  100
# 2799        f               f              f                 f  ...  114
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2800 entries, 0 to 2799
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   age                        2800 non-null   object
#  1   sex                        2800 non-null   object
#  2   on_thyroxine               2800 non-null   object
#  3   query_on_thyroxine         2800 non-null   object
#  4   on_antithyroid_medication  2800 non-null   object
#  5   sick                       2800 non-null   object
#  6   pregnant                   2800 non-null   object
#  7   thyroid_surgery            2800 non-null   object
#  8   I131_treatment             2800 non-null   object
#  9   query_hypothyroid          2800 non-null   object
#  10  query_hyperthyroid         2800 non-null   object
#  11  lithium                    2800 non-null   object
#  12  goitre                     2800 non-null   object
# ...

# %% [markdown]
# -----

# %%
import requests

# %%
us_query = requests.get('https://api.census.gov/data/2010/dec/sf1?get=NAME&for=county:*')

# %%
us_query.text
# Out:
# '[["NAME","state","county"],\n["Sebastian County, Arkansas","05","131"],\n["Sevier County, Arkansas","05","133"],\n["Sharp County, Arkansas","05","135"],\n["Stone County, Arkansas","05","137"],\n["Union County, Arkansas","05","139"],\n["Van Buren County, Arkansas","05","141"],\n["Washington County, Arkansas","05","143"],\n["White County, Arkansas","05","145"],\n["Yell County, Arkansas","05","149"],\n["Colusa County, California","06","011"],\n["Butte County, California","06","007"],\n["Alameda County, California","06","001"],\n["Alpine County, California","06","003"],\n["Amador County, California","06","005"],\n["Calaveras County, California","06","009"],\n["Contra Costa County, California","06","013"],\n["Del Norte County, California","06","015"],\n["Kings County, California","06","031"],\n["Glenn County, California","06","021"],\n["Humboldt County, California","06","023"],\n["Imperial County, California","06","025"],\n["El Dorado County, California","06","017"],\n["Fresno County, Ca
# ...

# %%
import ast # bezpieczne przetwarzanie tekstów na dane

# %%
us_data = ast.literal_eval(us_query.text)

# %%
[us_data[i] for i in range(len(us_data))]
# Out:
# [['NAME', 'state', 'county'],
#  ['Sebastian County, Arkansas', '05', '131'],
#  ['Sevier County, Arkansas', '05', '133'],
#  ['Sharp County, Arkansas', '05', '135'],
#  ['Stone County, Arkansas', '05', '137'],
#  ['Union County, Arkansas', '05', '139'],
#  ['Van Buren County, Arkansas', '05', '141'],
#  ['Washington County, Arkansas', '05', '143'],
#  ['White County, Arkansas', '05', '145'],
#  ['Yell County, Arkansas', '05', '149'],
#  ['Colusa County, California', '06', '011'],
#  ['Butte County, California', '06', '007'],
#  ['Alameda County, California', '06', '001'],
#  ['Alpine County, California', '06', '003'],
#  ['Amador County, California', '06', '005'],
#  ['Calaveras County, California', '06', '009'],
#  ['Contra Costa County, California', '06', '013'],
#  ['Del Norte County, California', '06', '015'],
#  ['Kings County, California', '06', '031'],
#  ['Glenn County, California', '06', '021'],
#  ['Humboldt County, California', '06', '023'],
# ...

# %%
us = pd.read_json(us_query.text) # dane z api zamienione na DataFrame
us
# Out:
# C:\Users\CSComarch\AppData\Local\Temp\ipykernel_1932\3540589918.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   us = pd.read_json(us_query.text)
#                                   0      1       2
# 0                              NAME  state  county
# 1        Sebastian County, Arkansas     05     131
# 2           Sevier County, Arkansas     05     133
# 3            Sharp County, Arkansas     05     135
# 4            Stone County, Arkansas     05     137
# ...                             ...    ...     ...
# 3217   Eau Claire County, Wisconsin     55     035
# 3218     Florence County, Wisconsin     55     037
# 3219  Fond du Lac County, Wisconsin     55     039
# 3220       Forest County, Wisconsin     55     041
# 3221    Jefferson County, Wisconsin     55     055
#
# [3222 rows x 3 columns]

# %%
import io
import pandas as pd

df = pd.read_json(io.StringIO(us_query.text), orient='values')
df
# Out:
#                                   0      1       2
# 0                              NAME  state  county
# 1        Sebastian County, Arkansas     05     131
# 2           Sevier County, Arkansas     05     133
# 3            Sharp County, Arkansas     05     135
# 4            Stone County, Arkansas     05     137
# ...                             ...    ...     ...
# 3217   Eau Claire County, Wisconsin     55     035
# 3218     Florence County, Wisconsin     55     037
# 3219  Fond du Lac County, Wisconsin     55     039
# 3220       Forest County, Wisconsin     55     041
# 3221    Jefferson County, Wisconsin     55     055
#
# [3222 rows x 3 columns]

# %%
df.columns = df.iloc[0]
df
# Out:
# 0                              NAME  state  county
# 0                              NAME  state  county
# 1        Sebastian County, Arkansas     05     131
# 2           Sevier County, Arkansas     05     133
# 3            Sharp County, Arkansas     05     135
# 4            Stone County, Arkansas     05     137
# ...                             ...    ...     ...
# 3217   Eau Claire County, Wisconsin     55     035
# 3218     Florence County, Wisconsin     55     037
# 3219  Fond du Lac County, Wisconsin     55     039
# 3220       Forest County, Wisconsin     55     041
# 3221    Jefferson County, Wisconsin     55     055
#
# [3222 rows x 3 columns]

# %%
df = df.drop(0).reset_index(drop=True)
df
# Out:
# 0                              NAME state county
# 0           Sevier County, Arkansas    05    133
# 1            Sharp County, Arkansas    05    135
# 2            Stone County, Arkansas    05    137
# 3            Union County, Arkansas    05    139
# 4        Van Buren County, Arkansas    05    141
# ...                             ...   ...    ...
# 3215   Eau Claire County, Wisconsin    55    035
# 3216     Florence County, Wisconsin    55    037
# 3217  Fond du Lac County, Wisconsin    55    039
# 3218       Forest County, Wisconsin    55    041
# 3219    Jefferson County, Wisconsin    55    055
#
# [3220 rows x 3 columns]
